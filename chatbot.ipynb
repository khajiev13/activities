# %%
from llamaapi import LlamaAPI

# Replace 'Your_API_Token' with your actual API token
llama = LlamaAPI("LL-SeWV0VFjmP1HCizReIZEHyokq6FU6K3lzZ76CgX9UGu988mfHyjtdRSUsq5VDwv4")

# %%
from langchain.chains import create_tagging_chain
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 from langchain.chains import create_tagging_chain
#
# File ~/Desktop/CS50/week7/activities/backend/venv/lib/python3.10/site-packages/langchain/chains/__init__.py:20
#       1 """**Chains** are easily reusable components linked together.
#       2
#       3 Chains encode a sequence of calls to components like models, document retrievers,
#    (...)
#      17     Chain --> <name>Chain  # Examples: LLMChain, MapReduceChain, RouterChain
#      18 """
# ---> 20 from langchain.chains.api.base import APIChain
#      21 from langchain.chains.api.openapi.chain import OpenAPIEndpointChain
#      22 from langchain.chains.combine_documents.base import AnalyzeDocumentChain
#
# File ~/Desktop/CS50/week7/activities/backend/venv/lib/python3.10/site-packages/langchain/chains/api/base.py:8
#       5 from urllib.parse import urlparse
#       7 from langchain_community.utilities.requests import TextRequestsWrapper
# ----> 8 from langchain_core.callbacks import (
#       9     AsyncCallbackManagerForChainRun,
#      10     CallbackManagerForChainRun,
#      11 )
#      12 from langchain_core.language_models import BaseLanguageModel
#      13 from langchain_core.prompts import BasePromptTemplate
#
# File ~/Desktop/CS50/week7/activities/backend/venv/lib/python3.10/site-packages/langchain_core/callbacks/__init__.py:13
#       1 from langchain_core.callbacks.base import (
#       2     AsyncCallbackHandler,
#       3     BaseCallbackHandler,
#    (...)
#      11     ToolManagerMixin,
#      12 )
# ---> 13 from langchain_core.callbacks.manager import (
#      14     AsyncCallbackManager,
#      15     AsyncCallbackManagerForChainGroup,
#      16     AsyncCallbackManagerForChainRun,
#      17     AsyncCallbackManagerForLLMRun,
#      18     AsyncCallbackManagerForRetrieverRun,
#      19     AsyncCallbackManagerForToolRun,
#      20     AsyncParentRunManager,
#      21     AsyncRunManager,
#      22     BaseRunManager,
#      23     CallbackManager,
#      24     CallbackManagerForChainGroup,
#      25     CallbackManagerForChainRun,
#      26     CallbackManagerForLLMRun,
#      27     CallbackManagerForRetrieverRun,
#      28     CallbackManagerForToolRun,
#      29     ParentRunManager,
#      30     RunManager,
#      31 )
#      32 from langchain_core.callbacks.stdout import StdOutCallbackHandler
#      33 from langchain_core.callbacks.streaming_stdout import StreamingStdOutCallbackHandler
#
# File ~/Desktop/CS50/week7/activities/backend/venv/lib/python3.10/site-packages/langchain_core/callbacks/manager.py:29
#      11 from typing import (
#      12     TYPE_CHECKING,
#      13     Any,
#    (...)
#      25     cast,
#      26 )
#      27 from uuid import UUID
# ---> 29 from langsmith.run_helpers import get_run_tree_context
#      30 from tenacity import RetryCallState
#      32 from langchain_core.callbacks.base import (
#      33     BaseCallbackHandler,
#      34     BaseCallbackManager,
#    (...)
#      40     ToolManagerMixin,
#      41 )
#
# File ~/Desktop/CS50/week7/activities/backend/venv/lib/python3.10/site-packages/langsmith/__init__.py:10
#       6 except metadata.PackageNotFoundError:
#       7     # Case where package metadata is not available.
#       8     __version__ = ""
# ---> 10 from langsmith.client import Client
#      11 from langsmith.evaluation.evaluator import EvaluationResult, RunEvaluator
#      12 from langsmith.run_helpers import trace, traceable
#
# File ~/Desktop/CS50/week7/activities/backend/venv/lib/python3.10/site-packages/langsmith/client.py:51
#      49 from langsmith import schemas as ls_schemas
#      50 from langsmith import utils as ls_utils
# ---> 51 from langsmith.evaluation import evaluator as ls_evaluator
#      53 if TYPE_CHECKING:
#      54     import pandas as pd  # type: ignore
#
# File ~/Desktop/CS50/week7/activities/backend/venv/lib/python3.10/site-packages/langsmith/evaluation/__init__.py:4
#       1 """Evaluation Helpers."""
#       3 from langsmith.evaluation.evaluator import EvaluationResult, RunEvaluator, run_evaluator
# ----> 4 from langsmith.evaluation.string_evaluator import StringEvaluator
#       6 __all__ = ["run_evaluator", "EvaluationResult", "RunEvaluator", "StringEvaluator"]
#
# File ~/Desktop/CS50/week7/activities/backend/venv/lib/python3.10/site-packages/langsmith/evaluation/string_evaluator.py:4
#       1 """This module contains the StringEvaluator class."""
#       2 from typing import Callable, Dict, Optional
# ----> 4 from pydantic import BaseModel
#       6 from langsmith.evaluation.evaluator import EvaluationResult, RunEvaluator
#       7 from langsmith.schemas import Example, Run
#
# File ~/Desktop/CS50/week7/activities/backend/venv/lib/python3.10/site-packages/pydantic/__init__.py:383, in __getattr__(attr_name)
#     381     return import_module(f'.{attr_name}', package=package)
#     382 else:
# --> 383     module = import_module(module_name, package=package)
#     384     return getattr(module, attr_name)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/importlib/__init__.py:126, in import_module(name, package)
#     124             break
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File ~/Desktop/CS50/week7/activities/backend/venv/lib/python3.10/site-packages/pydantic/main.py:12
#       9 from copy import copy, deepcopy
#      10 from typing import Any, ClassVar
# ---> 12 import pydantic_core
#      13 import typing_extensions
#      14 from pydantic_core import PydanticUndefined
#
# File ~/Desktop/CS50/week7/activities/backend/venv/lib/python3.10/site-packages/pydantic_core/__init__.py:6
#       3 import sys as _sys
#       4 from typing import Any as _Any
# ----> 6 from ._pydantic_core import (
#       7     ArgsKwargs,
#       8     MultiHostUrl,
#       9     PydanticCustomError,
#      10     PydanticKnownError,
#      11     PydanticOmit,
#      12     PydanticSerializationError,
#      13     PydanticSerializationUnexpectedValue,
#      14     PydanticUndefined,
#      15     PydanticUndefinedType,
#      16     PydanticUseDefault,
#      17     SchemaError,
#      18     SchemaSerializer,
#      19     SchemaValidator,
#      20     Some,
#      21     TzInfo,
#      22     Url,
#      23     ValidationError,
#      24     __version__,
#      25     from_json,
#      26     to_json,
#      27     to_jsonable_python,
#      28     validate_core_schema,
#      29 )
#      30 from .core_schema import CoreConfig, CoreSchema, CoreSchemaType, ErrorType
#      32 if _sys.version_info < (3, 11):
#
# ImportError: dlopen(/Users/khajievroma/Desktop/CS50/week7/activities/backend/venv/lib/python3.10/site-packages/pydantic_core/_pydantic_core.cpython-310-darwin.so, 0x0002): tried: '/Users/khajievroma/Desktop/CS50/week7/activities/backend/venv/lib/python3.10/site-packages/pydantic_core/_pydantic_core.cpython-310-darwin.so' (mach-o file, but is an incompatible architecture (have 'x86_64', need 'arm64')), '/System/Volumes/Preboot/Cryptexes/OS/Users/khajievroma/Desktop/CS50/week7/activities/backend/venv/lib/python3.10/site-packages/pydantic_core/_pydantic_core.cpython-310-darwin.so' (no such file), '/Users/khajievroma/Desktop/CS50/week7/activities/backend/venv/lib/python3.10/site-packages/pydantic_core/_pydantic_core.cpython-310-darwin.so' (mach-o file, but is an incompatible architecture (have 'x86_64', need 'arm64'))
